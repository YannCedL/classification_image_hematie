# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from skimage.transform import resize

# %%
class Image_object:
    def __init__(self, image, label):
        self.image = image
        self.label = label

# %%
i=-1
list_image = []
def import_data(path,list_image,i):
    for _,filename in enumerate(os.listdir(path)):
        img = cv2.imread(os.path.join(path,filename))
        if img is not None: 
            print(img.shape)
            img = cv2.resize(img, (224,224))
            list_image.append(np.array(img) / 255)
            i=i+1
            print(i)
    return i

    #         images.append(img)
    # return images

# %%
i=import_data(r"malaria_hematie_dataset\uninfected",list_image,i)
# Out:
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# malaria_hematie_dataset\uninfected
# ...

# %%
i=import_data("malaria_hematie_dataset\parasitized",list_image,i)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Yann LAVRY\AppData\Local\Temp\ipykernel_26852\1415075598.py:1: SyntaxWarning: invalid escape sequence '\p'
#   i=import_data("malaria_hematie_dataset\parasitized",list_image,i)
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# malaria_hematie_dataset\parasitized
# ...

# %%
print(list_image.__len__())
# Out:
# 0

# %%
print(list_image[13778][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(list_image[13778][0])
#
# IndexError: list index out of range

# %%
print(i)
# Out:
# 13778

# %%
# Out:
#   Cell In[165], line 1
#     i=import_data("malaria_hematie_dataset\uninfected",list_image,i)
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 23-24: truncated \uXXXX escape
